# %% [markdown]
# db connection
# json read-write
#
# calculators
#
# visualizers

# %%
import os

# Same URL as start_backend.sh
os.environ.setdefault(
    "DATABASE_URL",
    "postgresql://cim_wizard_user:cim_wizard_password@localhost:15432/cim_wizard_integrated",
)
# Out:
# 'postgresql://cim_wizard_user:cim_wizard_password@localhost:15432/cim_wizard_integrated'

# %%
import os

from sqlalchemy import create_engine, text

import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt

# %%
DATABASE_URL = os.environ["DATABASE_URL"]
print("DATABSE_URL ->", DATABASE_URL.replace("cim_wizard_password", "********"))

engine = create_engine(DATABASE_URL)


#smoke test
with engine.connect() as conn:
    ok = conn.execute(text("SELECT 1")).scalar()
assert ok == 1
print("database connection OK.")
# Out:
# DATABSE_URL -> postgresql://cim_wizard_user:********@localhost:15432/cim_wizard_integrated
# database connection OK.

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)

# Usage pattern:
# db = Session()
# try:
#     ... your work ...
#     db.commit()
# finally:
#     db.close()

# %%
tables = pd.read_sql("""
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_schema IN ('cim_vector', 'cim_census', 'cim_raster', 'outputs')
    ORDER BY 1, 2
""", engine)
tables
# Out:
#    table_schema                      table_name
# 0    cim_census                      census_geo
# 1    cim_census                       censusgeo
# 2    cim_raster           building_height_cache
# 3    cim_raster                             dsm
# 4    cim_raster                      dsm_raster
# 5    cim_raster                             dtm
# 6    cim_raster                      dtm_raster
# 7    cim_raster                    raster_model
# 8    cim_vector             cim_wizard_building
# 9    cim_vector  cim_wizard_building_properties
# 10   cim_vector     cim_wizard_project_scenario
# 11   cim_vector                        grid_bus
# 12   cim_vector                       grid_line
# 13   cim_vector                              pv
# 14      outputs                         battery
# 15      outputs           building_frassinetto3
# 16      outputs         heating_frassinetto_hp2
# 17      outputs                  simulation_run

# %%
ps_gdf = gpd.read_postgis("""
    SELECT * 
    FROM cim_vector.cim_wizard_project_scenario
    """, engine, geom_col="project_boundary")

ps_gdf[["project_id","scenario_id","project_name", "scenario_name"]]
# Out:
#                               project_id  \
# 0   4be7d1ff-e8bf-4374-a13e-67e7b0d52eb1
# 1   5a00fa63-2ef4-4d38-baa0-48ae5d80d21a
# 2   aeba11e7-ab0e-46ca-b89f-4c856c0289bf
# 3   e983d9e4-70ce-43e1-b778-03c25d992433
# 4   c12dfe7c-bb20-4609-a9d5-9084c170ca0c
# 5   eb3192d7-c3f3-442e-8d7d-1b90e46f0f3a
# 6   5671f758-0898-43a5-83c7-098daac9d780
# 7   f2e6c641-e480-4d5c-92cb-39ae43b3adf7
# 8   0c1115d7-8fe3-4f73-8c91-fb387bdcb582
# 9   32d6f262-4638-46ee-827c-abc42559c0bc
# 10  7cdddc7d-29cc-4dae-8264-2dd44b098852
# 11  fda47e01-4e7e-409c-82f8-3a95a1148d3d
# 12  a06ded75-705c-49a7-a14f-e6535bf1bb15
# 13  a06ded75-705c-49a7-a14f-e6535bf1bb15
# 14  05272032-e4f6-484e-b749-3ab76ac29de5
# 15  f78fbf8b-a88b-4177-847d-8c1011dbcbf0
# 16  ac51d4a0-5946-4256-94e4-725c21c4b7eb
# 17  7782f7f6-9a01-46f0-87f9-a7241db52c00
# 18  3126b3c3-6e0e-49c4-ba7f-6a81857730e0
# 19  050abad5-7ab2-4368-8f3e-b660993e3369
# 20  862fee6c-80f9-466e-8ec2-923af777d35f
# 21  bf584aa3-c58a-42fd-8412-8cf3cd5acaf2
# ...

# %%
PROJECT_ID = "9d3d01b4-c72b-4f7b-ae42-51c360e60300"
SCENARIO_ID = "c75e755b-9b87-4c22-a8c8-5ad52c2b4467"

# %%
_sql_b = text("""
    SELECT
        b.building_id::text AS building_id,
        b.lod,
        b.building_geometry,
        p.project_id,
        p.scenario_id::text AS scenario_id,
        p.height,
        p.area,
        p.volume,
        p.type,
        p.n_people,
        p.const_year
    FROM cim_vector.cim_wizard_building AS b
    INNER JOIN cim_vector.cim_wizard_building_properties AS p
      ON p.building_id = b.building_id AND p.lod = b.lod
    WHERE p.project_id = :project_id
      AND p.scenario_id = CAST(:scenario_id AS uuid)
""")
b_gdf = gpd.read_postgis(
    _sql_b, engine,
    geom_col="building_geometry",
    params={"project_id": PROJECT_ID, "scenario_id": SCENARIO_ID},
)
print(f"{len(b_gdf)} buildings, CRS={b_gdf.crs}")
b_gdf.head()
# Out:
# 10 buildings, CRS=EPSG:4326
#                             building_id  lod  \
# 0  3b0af389-67cb-4365-9650-fbed6ed138c8    0
# 1  6c8d1323-f200-4526-bbed-f3c6242bdc25    0
# 2  70490456-cd51-491e-92db-872196d2aba7    0
# 3  84c88c0e-b93b-4cf2-a7ee-dcb925bdc53c    0
# 4  c3c64a62-95b8-4d5a-9fb7-bcd3f0d752ed    0
#
#                                    building_geometry  \
# 0  POLYGON ((7.6802 45.0571, 7.68015 45.05697, 7....
# 1  POLYGON ((7.67951 45.05681, 7.67962 45.05708, ...
# 2  POLYGON ((7.68035 45.05747, 7.68028 45.0573, 7...
# 3  POLYGON ((7.68042 45.05765, 7.68035 45.05747, ...
# 4  POLYGON ((7.68015 45.05697, 7.68005 45.05671, ...
#
#                              project_id                           scenario_id  \
# 0  9d3d01b4-c72b-4f7b-ae42-51c360e60300  c75e755b-9b87-4c22-a8c8-5ad52c2b4467
# 1  9d3d01b4-c72b-4f7b-ae42-51c360e60300  c75e755b-9b87-4c22-a8c8-5ad52c2b4467
# 2  9d3d01b4-c72b-4f7b-ae42-51c360e60300  c75e755b-9b87-4c22-a8c8-5ad52c2b4467
# ...

# %%
fig,ax = plt.subplots(figsize=(10,10))

b_gdf.plot(
    ax=ax,
    column="type",    #tabula_type
    legend = True,
    cmap="Set2",
    edgecolor="white",
    linewidth=0.3,
    alpha=0.8,
)


# Optional: project boundary from ps_gdf
# subset = ps_gdf[(ps_gdf.project_id == PROJECT_ID) & (ps_gdf.scenario_id == SCENARIO_ID)]
# subset.boundary.plot(ax=ax, color="red", linewidth=2)

ax.set_title("Buildings by type")
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %%
b_gdf.explore(
    column="type",          # color buildings
    tooltip=["building_id", "type", "height", "area", "volume"],
    tiles="OpenStreetMap",
    style_kwds={"fillOpacity": 0.7, "weight": 0.5},
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/webgis/lib/python3.11/site-packages/geopandas/explore.py:294, in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     293 import matplotlib.pyplot as plt
# --> 294 from mapclassify import classify
#     295 from matplotlib import colormaps as cm
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 b_gdf.explore(
# ...
